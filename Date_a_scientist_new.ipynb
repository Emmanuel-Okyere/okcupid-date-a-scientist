# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
profiles = pd.read_csv("profiles.csv")
pd.options.display.max_columns = 60
pd.options.display.max_colwidth = 500
profiles.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
# ...

# %%
profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   body_type    54650 non-null  object
#  2   diet         35551 non-null  object
#  3   drinks       56961 non-null  object
#  4   drugs        45866 non-null  object
#  5   education    53318 non-null  object
#  6   essay0       54458 non-null  object
#  7   essay1       52374 non-null  object
#  8   essay2       50308 non-null  object
#  9   essay3       48470 non-null  object
#  10  essay4       49409 non-null  object
#  11  essay5       49096 non-null  object
#  12  essay6       46175 non-null  object
#  13  essay7       47495 non-null  object
#  14  essay8       40721 non-null  object
#  15  essay9       47343 non-null  object
#  16  ethnicity    54266 non-null  object
#  17  height       59943 non-null  float64
# ...

# %%
profiles.columns
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')

# %%
columns_to_drop = ['essay0','essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7','essay8', 'essay9']
newProfile = profiles.drop(columns_to_drop, axis = 1)
newProfile.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job       last_online  \
# 0               transportation  2012-06-28-20-30
# ...

# %%
newProfile["body_type"].fillna("other", inplace = True)
newProfile["diet"].fillna("other", inplace = True)
newProfile["drinks"].fillna("other", inplace = True)
newProfile["drugs"].fillna("never", inplace = True)
newProfile["education"].fillna("other", inplace = True)
newProfile["height"].fillna(np.mean(newProfile["height"]), inplace = True)
newProfile["job"].fillna("other", inplace = True)
newProfile["offspring"].fillna("other", inplace = True)
newProfile["pets"].fillna("other", inplace = True)
newProfile["religion"].fillna("other", inplace = True)
newProfile["smokes"].fillna("no", inplace = True)
newProfile["ethnicity"].fillna("other", inplace = True)
newProfile["sign"].fillna("other", inplace = True)
newProfile["speaks"].fillna("other", inplace = True)
newProfile["status"].replace("unknown","single", inplace = True)
newProfile["income"].replace(-1, np.mean(newProfile["income"]), inplace = True)
newProfile["height"] = newProfile["height"].apply(lambda x: np.mean(newProfile["height"]) if x < 30 else x)
newProfile["norm_income"] = newProfile["income"].apply(lambda x: (x-np.mean(newProfile["income"]))/np.std(newProfile["income"]) if x > 1 else 0)
newProfile["sign_clean"] = newProfile["sign"].str.split().str.get(0)
newProfile["religion_clean"] = newProfile["religion"].str.split().str.get(0)
newProfile["location_clean"] = newProfile["location"].str.split(",").str.get(1)

newProfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             59946 non-null  int64
#  1   body_type       59946 non-null  object
#  2   diet            59946 non-null  object
#  3   drinks          59946 non-null  object
#  4   drugs           59946 non-null  object
#  5   education       59946 non-null  object
#  6   ethnicity       59946 non-null  object
#  7   height          59946 non-null  float64
#  8   income          59946 non-null  float64
#  9   job             59946 non-null  object
#  10  last_online     59946 non-null  object
#  11  location        59946 non-null  object
#  12  offspring       59946 non-null  object
#  13  orientation     59946 non-null  object
#  14  pets            59946 non-null  object
#  15  religion        59946 non-null  object
#  16  sex             59946 non-null  object
# ...

# %%
newProfile["sign_clean"].unique()
print(newProfile["religion_clean"].unique())
# Out:
# ['agnosticism' 'other' 'atheism' 'christianity' 'catholicism' 'buddhism'
#  'judaism' 'hinduism' 'islam']

# %%
newProfile["income"].unique()
# Out:
# array([  20033.22253361,   80000.        ,   20000.        ,
#          40000.        ,   30000.        ,   50000.        ,
#          60000.        , 1000000.        ,  150000.        ,
#         100000.        ,  500000.        ,   70000.        ,
#         250000.        ])

# %%
newProfile.describe()
# Out:
#                 age        height          income   norm_income
# count  59946.000000  59946.000000    59946.000000  5.994600e+04
# mean      32.340290     68.302305    36222.756581 -3.548491e-13
# std        9.452779      3.940570    94285.871654  1.000008e+00
# min       18.000000     36.000000    20000.000000 -1.720607e-01
# 25%       26.000000     66.000000    20033.222534 -1.717083e-01
# 50%       30.000000     68.000000    20033.222534 -1.717083e-01
# 75%       37.000000     71.000000    20033.222534 -1.717083e-01
# max      110.000000     95.000000  1000000.000000  1.022195e+01

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x="age", data = newProfile, hue = "sex")
plt.xticks(rotation = "90")
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x="sex", data = newProfile)
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x="status",data = newProfile, hue ="sex" )
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x="body_type", data = newProfile, hue= "sex")
plt.xticks(rotation = 70)
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x="sign_clean", data = newProfile, hue = "sex")
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x ="income", data = newProfile, hue = "sex")
plt.xticks(rotation = 70)
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.countplot(x="religion_clean", data = newProfile)
plt.show()

# %% [markdown]
# ### Dropping Nans

# %%
non_na_profile = profiles.copy()

# %%
non_na_profile.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
# ...

# %%
non_na_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   body_type    54650 non-null  object
#  2   diet         35551 non-null  object
#  3   drinks       56961 non-null  object
#  4   drugs        45866 non-null  object
#  5   education    53318 non-null  object
#  6   essay0       54458 non-null  object
#  7   essay1       52374 non-null  object
#  8   essay2       50308 non-null  object
#  9   essay3       48470 non-null  object
#  10  essay4       49409 non-null  object
#  11  essay5       49096 non-null  object
#  12  essay6       46175 non-null  object
#  13  essay7       47495 non-null  object
#  14  essay8       40721 non-null  object
#  15  essay9       47343 non-null  object
#  16  ethnicity    54266 non-null  object
#  17  height       59943 non-null  float64
# ...
